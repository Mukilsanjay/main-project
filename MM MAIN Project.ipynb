# %%
import os
import pandas as pd
import seaborn as sns

# %%
dataframe=pd.read_csv("C:\\Users\\Admin\\Downloads\\loan_data_set.csv")
print(dataframe)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.barplot(dataframe['Loan_ID'])
# Out:
# <Axes: ylabel='Loan_ID'>

# %%
sns.countplot(dataframe['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.lineplot(dataframe['Married'])
# Out:
# <Axes: ylabel='Married'>

# %%
sns.boxplot(dataframe['Dependents'])
# Out:
# <Axes: ylabel='Dependents'>

# %%
sns.scatterplot(dataframe['Education'])
# Out:
# <Axes: ylabel='Education'>

# %%
sns.barplot(dataframe['ApplicantIncome'])
# Out:
# <Axes: ylabel='ApplicantIncome'>

# %%
sns.lineplot(dataframe['Self_Employed'])
# Out:
# <Axes: ylabel='Self_Employed'>

# %%
sns.scatterplot(dataframe['CoapplicantIncome'])
# Out:
# <Axes: ylabel='CoapplicantIncome'>

# %%
sns.scatterplot(dataframe['LoanAmount'])
# Out:
# <Axes: ylabel='LoanAmount'>

# %%
sns.scatterplot(dataframe['Loan_Amount_Term'])
# Out:
# <Axes: ylabel='Loan_Amount_Term'>

# %%
sns.scatterplot(dataframe['Credit_History'])
# Out:
# <Axes: ylabel='Credit_History'>

# %%
sns.barplot(dataframe['Loan_Status'])
# Out:
# <Axes: ylabel='Loan_Status'>
